# %%
import pickle

# %%
with open('./models/best_model.pkl', 'rb') as f:
    model_weight = pickle.load(f)

# %%
model_weight['fc3']['W'].shape
# Out:
# (64, 10)

# %%
with open('./models/model_config.pkl', 'rb') as f:
    model_config = pickle.load(f)

# %%
model_config
# Out:
# {'input_size': 3072,
#  'hidden1_size': 512,
#  'hidden2_size': 64,
#  'output_size': 10,
#  'activation': 'relu',
#  'weight_decay': 0.0005,
#  'dropout': 0.0}

# %%
with open('./models/training_history.pkl', 'rb') as f:
    training_history = pickle.load(f)

# %%
training_history.keys()
# Out:
# dict_keys(['train_loss', 'train_acc', 'val_loss', 'val_acc', 'learning_rates', 'best_epoch', 'best_val_acc'])

# %%
with open('./logs/parameter/grid_search_results.pkl', 'rb') as f:
    grid_search_results = pickle.load(f)

# %%
grid_search_results.keys()
# Out:
# dict_keys(['best_params', 'best_score', 'all_trials', 'total_time'])
